# %%
"""
- clone repo - 
cd 30122-project-truth-inquery
poetry install
poetry run python truth_inquery/crawler
"""
import lxml.html
import pandas as pd
import re
import scrapelib
from lxml import etree
import time
from collections import defaultdict


from bs4 import BeautifulSoup
from bs4.element import Comment
import urllib.request
from urllib.request import build_opener, HTTPCookieProcessor
#from truth_inquery.analysis_model.states import STATES


#### Constants #####

LIMIT = 25
PATTERN = r'[\[0-9()="?!}{<>.,~`@#$%&*^_+:;|\]\\\/]'
s = scrapelib.Scraper(retry_attempts=0, retry_wait_seconds=0)
opener = build_opener(HTTPCookieProcessor())
CPCIN = "truth_inquery/data/CPC_"
CPCOUT = "truth_inquery/output/CPC_state_clinics.csv"

STATES = {
    'AK': 'Alaska',
    'AL': 'Alabama',
    'AR': 'Arkansas',
    'AZ': 'Arizona',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DC': 'District of Columbia',
    'DE': 'Delaware',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'IA': 'Iowa',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'MA': 'Massachusetts',
    'MD': 'Maryland',
    'ME': 'Maine',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MO': 'Missouri',
    'MS': 'Mississippi',
    'MT': 'Montana',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'NE': 'Nebraska',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NV': 'Nevada',
    'NY': 'New York',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VA': 'Virginia',
    'VT': 'Vermont',
    'WA': 'Washington',
    'WI': 'Wisconsin',
    'WV': 'West Virginia',
    'WY': 'Wyoming'
}

name_to_abbrev = {v: k for k, v in STATES.items()}

# %%
def csv_extract(input_file):
    """
    Loads CPC csv input file and extracts data from columns

    Inputs:
        input_file (str): File path to .csv file

    Returns: dataframe with standardized zip and url columns
    """
    f = pd.read_csv(input_file)
    df = f[f['Website'].notna()]
    df = df[['Name ', 'Zip Code', 'State', 'Website']]

    # Rename columns, front-fill zipcode with zeros.
    df = df.rename(columns={'Name ':'name', 'Zip Code':'zip', 'State':'state', 'Website':'website_s'})
    df['zip'] = df['zip'].astype(str)
    df['zip'] = df['zip'].str.zfill(5)
    df['website_s'] = df['website_s']
    df.loc[:, ['url']] = df['website_s'].str.strip().apply(lambda x: x.split(' ')[0])
    
    
    return df

# %%
california_cpc_df = csv_extract("CPC_California (CA).csv")

# %%
def clean_df(df):
    """
    Takes in pandas dataframe, replace NaN with 0 and 
    generate new column sum 'count' across all columns

    Input: pandas dataframe
    Returns token,count pandas dataframe
    """
    output = df.fillna(0)
    output['count'] = output.sum(axis=1)
    output = output[['count']]
    return output

# %%
from urllib.parse import urlparse

def remove_after_domain(url):
    pattern = r'(https?://[^\s/]+)'
    match = re.match(pattern, url)
    if match:
        return match.group(0)
    else:
        return url

# %%
def get_root(url):
    """
    Extracts html root from url if possible

    Inputs:
        url (str): URL

    Returns: set of URLs otherwise None
    """
    try:
        response = s.get(remove_after_domain(url), timeout=5)
        root = lxml.html.fromstring(response.text)
        return root
    except:
        return None

# %%
# TEST 1
remove_after_domain("https://obria.org/locations/anaheim-ca/")
# Out:
# 'https://obria.org'

# %%
# TEST 2
lst_urls = get_root("https://wrcathens.org")
#print(lst_urls.text_content())
print(type(lst_urls))
# Out:
# <class 'lxml.html.HtmlElement'>

# %%
def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True


def text_from_html(body):
    soup = BeautifulSoup(body, 'html.parser')
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)  
    return u" ".join(t.strip() for t in visible_texts)

html = urllib.request.urlopen("https://wrcathens.org/").read()
print(text_from_html(html))
# Out:
#                       Home    About    Services    Your Choices    Get Involved    Donate    Contact                          Home    About    Services    Your Choices    Get Involved    Donate    Contact                            SCHEDULE AN APPOINTMENT            SCHEDULE AN APPOINTMENT            SCHEDULE AN APPOINTMENT            SCHEDULE AN APPOINTMENT                 Schedule an Appointment     WE’RE HERE TO HELP. The Women’s Resource Center in Athens has supported local families for over 30 years through pregnancy and parenting related services. We offer free, compassionate, and confidential help for both women and men as they make family planning decisions.     Call any time: 256-233-5775 727-D West Market Street Athens, AL 35611 (On Fitness Way) Hours of operation We will be closed on June 28th & 29th & July 4th-6th Phone lines will remain open for emergency calls Tuesday 10am-4:00pm | Wednesday 10am-2pm | Thursday 10am-4:00pm            Pregnant?         Considering Abortion         Ultrasound                                      Back to Top      Abortion      Adoption      Annual Banquet      Baby Bottles      Charity House      Educational Courses      SaveOne post abortive support group      Material Assistance      Parenting      Pregnancy      3000 Crosses      Ultrasounds      Women's Resource Center, 727 Market Street West, Athens, AL, 35611, United States 256-233-5775    Hours of operation:  Tuesday 10am-4:00pm  |  Wednesday 10am-2pm  |  Thursday 10am-4:00pm The education provided is not intended to diagnose any condition or pregnancy and should not take the place of your medical practitioner. We provide credible health education; however, it is not intended to be a substitute for professional, medical, legal, or counseling advice. Athens WRC does not perform or refer for abortions. We are here to help you make an informed decision that is best for you and your future. Free & Confidential Copyright © 2022
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)

# %%
def crawlss(url, limit):

    """
    This function starts at the base URL of a CPC and
    crawls through each embedded url, scraping the html structure of the main 
    website and the texts of the main and the rest of the urls.

    Parameters:
        * url: url of CPC's main website
        * limit: integer with the maximum number of embedded urls visited
    """
    root = get_root(url)
    
    if root is None:
        return None
    
    # Tokenize the base URL (input) and identify unique sub-urls
    dct = {}
    dct['url'] = str(url)
    dct['html_structure'] = s.get(remove_after_domain(url), timeout=5).text
    try:
        dct['text_base'] = text_from_html(opener.open(url).read())
    except:
        pass

    urls = set(root.xpath('//a/@href'))
  
    urls_visited = 0 
    for u in urls:
        subroot = get_root(u)
        if subroot is not None:
            urls_visited += 1
            
            try:
                dct['text_url'+str(urls_visited)] = text_from_html(opener.open(u).read())
            except urllib.error.HTTPError:
                pass
            

        if urls_visited == limit:
            break

    # Return df and number of urls visited including base
    df = pd.DataFrame(dct, index=[0])
    return df, urls_visited

#crawlss("https://reallifecpc.org/", 20)

# %%
def network_crawl(urllst, limit=LIMIT):
    """
    Crawls each URL in list and creates a pandas dataframe with the texts and
    the html structure

    Inputs
        - urllst: (list of strings) URLs 
        - limit: (int) max num of hrefs to crawl for each URL

    Returns: pandas dataframe and dictionary with number of urls visited
    """
    # Accumulators 
    df = pd.DataFrame()
    results = defaultdict(dict)

    # Crawl each URL
    for b, b_url in enumerate(urllst):

        print("Base URL", b, "crawling")
        crawldf = crawlss(b_url, limit)
        # If root is none skip
        if crawldf is None:
            continue

        # Unpack output of crawl and add to data accumulators
        nextdf, urls_visited = crawldf
        df = pd.concat([df,nextdf])
        

        results[b+1] = {'url': b_url, 'urls_visited': urls_visited}
        print("Finished")


    return df.reset_index().drop(['index'], axis=1), results

# %%
# TEST 3
url_list = ["https://optionspc.org/", "https://pregnantnowwhat.org/", "https://arkadelphiapregnancy.com/", "https://hannahprc.com/"]
df_test = network_crawl(url_list)
#df_test
# Out:
# Base URL 0 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 1 crawling
# Base URL 2 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 3 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished

# %%
# TEST 4
df_test[0]
#lxml.html.fromstring(df_test[0].loc[0,"html_structure"])
#type(list(df_test[0].loc[:, "html_structure"])[0])
#df_test[0].to_csv("dataframe_test")
# Out:
#                                  url  \
# 0             https://optionspc.org/
# 1  https://arkadelphiapregnancy.com/
# 2             https://hannahprc.com/
#
#                                       html_structure  \
# 0  \r\n<!doctype html>\r\n<html lang="en-US">\r\n...
# 1  <!DOCTYPE html>\n  <html itemscope itemtype="h...
# 2  <!DOCTYPE HTML>\n<html>\n<head>\n\t<meta chars...
#
#                                            text_base  \
# 0                  Call Cabot  Call Beebe  Call J...
# 1                                                ...
# 2        Need help? 870-862-1317  Donate      Ser...
#
#                                            text_url1  \
# 0                          Call Cabot  Call Beebe...
# 1                                                ...
# 2                888-910-9995      PORTFOLIO  SER...
#
#                                            text_url3  \
# 0                  Call Cabot  Call Beebe  Call J...
# 1                                                ...
# 2
#
#                                            text_url4  \
# 0                  Call Cabot  Call Beebe  Call J...
# 1   Notice 登录后才能继续。 登录 Facebook 登录后才能继续。 登录 忘记帐户？...
# 2       Donate    Our Purpose  What is Addiction?...
#
#                                            text_url5  \
# 0                  Call Cabot  Call Beebe  Call J...
# 1                                                NaN
# 2                                                NaN
#
#                                            text_url6  \
# 0                  Call Cabot  Call Beebe  Call J...
# 1                                                NaN
# 2                                                NaN
#
#                                            text_url7  \
# 0                  Call Cabot  Call Beebe  Call J...
# 1                                                NaN
# 2                                                NaN
#
#                                            text_url8  \
# 0                  Call Cabot  Call Beebe  Call J...
# 1                                                NaN
# 2                                                NaN
#
#                                           text_url11  \
# 0                  Call Cabot  Call Beebe  Call J...
# 1                                                NaN
# 2                                                NaN
#
#                                           text_url12  \
# 0                  Call Cabot  Call Beebe  Call J...
# 1                                                NaN
# 2                                                NaN
#
#                                           text_url13  \
# 0                  Call Cabot  Call Beebe  Call J...
# 1                                                NaN
# 2                                                NaN
#
#                                           text_url14  \
# 0   Notice 登录后才能继续。 登录 Facebook 登录后才能继续。 登录 忘记帐户？...
# 1                                                NaN
# 2                                                NaN
#
#                                           text_url15  \
# 0                                                ...
# 1                                                NaN
# 2                                                NaN
#
#                                           text_url16  \
# 0                  Call Cabot  Call Beebe  Call J...
# 1                                                NaN
# 2                                                NaN
#
#                                           text_url17  \
# 0                  Call Cabot  Call Beebe  Call J...
# 1                                                NaN
# 2                                                NaN
#
#                                            text_url2
# 0                                                NaN
# 1   Notice 登录后才能继续。 登录 Facebook 登录后才能继续。 登录 忘记帐户？...
# 2                                                ...

# %%
# TEST 5
urls = california_cpc_df['url'].tolist()[0:30]
df_cal = network_crawl(urls)
#df_cal[0].isna().sum()
# Out:
# Base URL 0 crawling
# Base URL 1 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 2 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 3 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 4 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 5 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 6 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 7 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 8 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 9 crawling
# Base URL 10 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Finished
# Base URL 11 crawling
# Base URL 12 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 13 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 14 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 15 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 16 crawling
# Finished
# Base URL 17 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 18 crawling
# Finished
# Base URL 19 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 20 crawling
# Base URL 21 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 22 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 23 crawling
# Base URL 24 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 25 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 26 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 27 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 28 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished
# Base URL 29 crawling
# /var/folders/5d/ntxdl44j0m57__z99jhcwvw00000gn/T/ipykernel_23359/1053274981.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# Finished

# %%
# TEST 6
df_cal[0]
# Out:
#                                                   url  \
# 0         https://www.obria.org/locations/anaheim-ca/
# 1                                https://cdohope.org/
# 2                http://www.treeoflifepsc.com/contact
# 3                               http://wehelpyou.org/
# 4                 https://pregnancycenterbarstow.com/
# 5                     http://birthright.org/brentwood
# 6               https://www.womensresourceclinic.org/
# 7                         http://birthright.org/chico
# 8                     http://birthlineofsandiego.org/
# 9                  http://www.graceelliottcenter.org/
# 10                      http://birthright.org/concord
# 11                         https://optionshealth.org/
# 12                      https://www.clspregnancy.com/
# 13  https://optionsforpregnancy.com/free-clinic/th...
# 14                           http://mtnpregnancy.org/
# 15                        http://www.dawningsprc.com/
# 16                  https://www.livinghelpcenter.org/
# 17                http://www.unplannedparenthood.org/
# 18       https://www.elcentropregnancy.org/contact-us
# 19                             https://www.colfs.org/
# 20        http://alternativespregnancycareclinic.org/
# 21                          http://www.pcceureka.org/
# 22                     https://www.jrophemedical.org/
# 23                     https://www.hopefallbrook.com/
# 24                       http://www.fallbrookprc.com/
#
#                                        html_structure  \
# 0   \t\t\n\t\t<!DOCTYPE html>\n<html lang="en">\n<...
# 1   <!DOCTYPE html>\n<html lang="en-US">\n<head>\n...
# 2   <!doctype html>\n<html xmlns:og="http://opengr...
# 3   <!DOCTYPE html>\n<html dir="ltr" lang="en-US"\...
# 4   <!DOCTYPE html>\n<html lang="en">\n<head>\n  \...
# 5   <!DOCTYPE html>\n<html lang="en-US">\n<head>\n...
# 6   <!DOCTYPE html>\n<html lang="en-GB" dir="ltr">...
# 7   <!DOCTYPE html>\n<html lang="en-US">\n<head>\n...
# 8   <!DOCTYPE html>\n\n<html class="no-js" lang="e...
# 9   <!DOCTYPE html>\n<html>\n\t<head>\n\t\t<!-- <h...
# 10  <!DOCTYPE html>\n<html lang="en-US">\n<head>\n...
# 11  <!doctype html>\n<html lang="en-US">\n<head>\n...
# 12  <!DOCTYPE html>\n<html lang="en-GB" dir="ltr">...
# 13  \n<!doctype html>\n<html lang="en-US">\n  <hea...
# 14  <!DOCTYPE html>\n<html lang="en-US">\n<head>\n...
# 15  <!DOCTYPE html><html lang="en-US"><head><link ...
# 16  <!DOCTYPE html>\n<html lang="en-US">\n<head>\n...
# 17  <!DOCTYPE html>\n<html class="avada-html-layou...
# 18                                          <!DOCT...
# 19  <!DOCTYPE html>\n<html lang="en-US">\n<head>\n...
# 20  \n<!doctype html>\n<html lang="en-US">\n  <hea...
# 21  \r\n\r\n<!DOCTYPE html>\r\n<head>\r\n    <meta...
# 22  <!DOCTYPE html>\r\n<html  lang="en-US">\r\n<he...
# 23  <!DOCTYPE html>\r\n<html  lang="en-US">\r\n<he...
# 24  <!DOCTYPE html>\r\n<html  lang="en-US">\r\n<he...
#
#                                             text_url1  \
# 0                            Donate              ...
# 1              Facebook                  Door Of H...
# 2                          Menu                   ...
# 3           SUPPORT US                CONTACT US  ...
# 4                                                 ...
# 5                  Birthright              24/7 HE...
# 6    You need to enable JavaScript to run this app...
# 7                  Birthright              24/7 HE...
# 8                                                 NaN
# 9           Grace Elliott Center 1 Home Services A...
# 10                 Birthright              24/7 HE...
# 11                                                ...
# 12                             GET STARTED TODAY |...
# 13                                                NaN
# 14          909-338-0848      Facebook           F...
# 15                                                NaN
# 16                        Skip to content     Livi...
# 17                     Skip to content           C...
# 18                                                NaN
# 19                                                ...
# 20                 Donate   Volunteer        Home ...
# 21        Sorry, CDM+ Engage is no longer supporte...
# 22                                 Home    Service...
# 23                                 If you are expe...
# 24                                 If you are expe...
#
#                                             text_url2  \
# 0                            Donate              ...
# 1              Facebook                  Door Of H...
# 2                                                 ...
# 3           SUPPORT US                CONTACT US  ...
# 4                                                 ...
# 5                                                 ...
# 6                         (530) 897-6101 24 Hour H...
# 7                                                 ...
# 8                                                 NaN
# 9   PayPal requires JavaScript for many of its fea...
# 10                                                ...
# 11                                                ...
# 12                                                ...
# 13                                                NaN
# 14          909-338-0848      Facebook           F...
# 15                                                NaN
# 16                        Skip to content     Livi...
# 17                     Skip to content           C...
# 18                             GET STARTED TODAY |...
# 19                                                ...
# 20                 Donate   Volunteer        Home ...
# 21                                 Home    Service...
# 22                                 Home    Service...
# 23                                 If you are expe...
# 24                                 If you are expe...
#
#                                             text_url3  \
# 0                            Donate              ...
# 1                                                 ...
# 2                                                 ...
# 3           SUPPORT US                CONTACT US  ...
# 4                                                 ...
# 5                                                 ...
# 6                              GET STARTED TODAY |...
# 7                                                 ...
# 8                                                 NaN
# 9          New York    Los Angeles    Houston    S...
# 10                                                ...
# 11                                                ...
# 12  Pinterest Today Watch Shop Explore When autoco...
# 13                                                NaN
# 14                                                ...
# 15                                                NaN
# 16                         Skip to content     Liv...
# 17                     Skip to content           C...
# 18   联系你我，分享生活，尽在 Facebook 登录 忘记密码？ 新建帐户 为名人、品牌或公司...
# 19                                                ...
# 20                 Donate   Volunteer        Home ...
# 21                                                NaN
# 22                                 Home    Service...
# 23                                 If you are expe...
# 24                                 If you are expe...
#
#                                             text_url4  \
# 0                            Donate              ...
# 1              Facebook                  Door Of H...
# 2                                                 NaN
# 3           SUPPORT US                CONTACT US  ...
# 4    登录 Facebook 登录 忘记帐户？ 或 新建帐户 中文(简体) English (U...
# 5                  Birthright              24/7 HE...
# 6                                                 NaN
# 7                  Birthright              24/7 HE...
# 8                                                 ...
# 9   Sign in Use your Google Account Email or phone...
# 10                 Birthright              24/7 HE...
# 11                                                ...
# 12                                                NaN
# 13                                                NaN
# 14          909-338-0848      Facebook           F...
# 15                                                NaN
# 16                        Skip to content     Livi...
# 17                     Skip to content           C...
# 18  Sign in Use your Google Account Email or phone...
# 19                                                ...
# 20                                    Alternatives...
# 21                                                NaN
# 22                                                ...
# 23                                 If you are expe...
# 24                                 If you are expe...
#
#                                             text_url5  \
# 0                            Donate              ...
# 1              Facebook                  Door Of H...
# 2                                                 NaN
# 3           SUPPORT US                CONTACT US  ...
# 4                                                 ...
# 5                                                 ...
# 6                                                 NaN
# 7                                                 ...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                ...
# 11                                                ...
# 12                                                NaN
# 13                                                NaN
# 14          909-338-0848      Facebook           F...
# 15                                                NaN
# 16                                                ...
# 17                     Skip to content           C...
# 18                                                NaN
# 19                                                ...
# 20                 Donate   Volunteer        Home ...
# 21                                                NaN
# 22                                  Home    Servic...
# 23                                 If you are expe...
# 24                                 If you are expe...
#
#                                             text_url6  \
# 0                            Donate              ...
# 1              Facebook                  Door Of H...
# 2                                                 NaN
# 3           SUPPORT US                CONTACT US  ...
# 4                                                 ...
# 5                                                 ...
# 6                                                 NaN
# 7                                                 ...
# 8   ?OUֵі�b8?g� �rJ]R�5�b�^}V6�!LhY�A�[�C�*
# \�%�...
# 9                                                 NaN
# 10                                                ...
# 11         This site requires javascript. Please e...
# 12                                                NaN
# 13                                                NaN
# 14          909-338-0848      Facebook           F...
# 15                                                NaN
# 16                                                NaN
# 17                     Skip to content           C...
# 18                                                NaN
# 19                                                ...
# 20                 Donate   Volunteer        Home ...
# 21                                                NaN
# 22                                 Home    Service...
# 23                                 If you are expe...
# 24                                 If you are expe...
#
#                                             text_url7  \
# 0                            Donate              ...
# 1              Facebook                  Door Of H...
# 2                                                 NaN
# 3           SUPPORT US                CONTACT US  ...
# 4                                                 ...
# 5                  Birthright              24/7 HE...
# 6                                                 NaN
# 7                  Birthright              24/7 HE...
# 8                                                 NaN
# 9                                                 NaN
# 10                 Birthright              24/7 HE...
# 11                                                ...
# 12                                                NaN
# 13                                                NaN
# 14          909-338-0848      Facebook           F...
# 15                                                NaN
# 16                        Skip to content     Livi...
# 17                     Skip to content           C...
# 18                                                NaN
# 19                                      Toggle nav...
# 20                 Donate   Volunteer        Home ...
# 21                                                NaN
# 22                                 Home    Service...
# 23                                 If you are expe...
# 24                                 If you are expe...
#
#                                             text_url8  ...  \
# 0                            Donate              ...  ...
# 1              Facebook                  Door Of H...  ...
# 2                                                 NaN  ...
# 3           SUPPORT US                CONTACT US  ...  ...
# 4                                                 NaN  ...
# 5                  Birthright              24/7 HE...  ...
# 6                                                 NaN  ...
# 7                  Birthright              24/7 HE...  ...
# 8       Print Editions The Southern Cross The Offi...  ...
# 9                                                 NaN  ...
# 10                 Birthright              24/7 HE...  ...
# 11                                                ...  ...
# 12                                                NaN  ...
# 13                                                NaN  ...
# 14          909-338-0848      Facebook           F...  ...
# 15                                                NaN  ...
# 16                         Skip to content     Liv...  ...
# 17                     Skip to content           C...  ...
# 18                                                NaN  ...
# 19                                                ...  ...
# 20                 Donate   Volunteer        Home ...  ...
# 21                                                NaN  ...
# 22                                 Home    Service...  ...
# 23                                 If you are expe...  ...
# 24                                 If you are expe...  ...
#
#                                            text_url17  \
# 0                            Donate              ...
# 1              Facebook                  Door Of H...
# 2                                                 NaN
# 3           SUPPORT US                CONTACT US  ...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                ...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                     Skip to content           C...
# 18                                                NaN
# 19                                                ...
# 20                 Donate   Volunteer        Home ...
# 21                                                NaN
# 22                                                NaN
# 23                                 If you are expe...
# 24                                 If you are expe...
#
#                                            text_url18  \
# 0                            Donate              ...
# 1              Facebook                  Door Of H...
# 2                                                 NaN
# 3           SUPPORT US                CONTACT US  ...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8       Print Editions The Southern Cross The Offi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                ...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                     Skip to content           C...
# 18                                                NaN
# 19                                                ...
# 20                 Donate   Volunteer        Home ...
# 21                                                NaN
# 22                                                NaN
# 23                                  If you are exp...
# 24                                  If you are exp...
#
#                                            text_url19  \
# 0                            Donate              ...
# 1                                                 NaN
# 2                                                 NaN
# 3           SUPPORT US                CONTACT US  ...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                ...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                     Skip to content           C...
# 18                                                NaN
# 19                                                ...
# 20                 Donate   Volunteer        Home ...
# 21                                                NaN
# 22                                                NaN
# 23                                 If you are expe...
# 24                                 If you are expe...
#
#                                            text_url20  \
# 0                            Donate              ...
# 1                                                 NaN
# 2                                                 NaN
# 3           SUPPORT US                CONTACT US  ...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 ...
# 9                                                 NaN
# 10                                                NaN
# 11                                                ...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                ...
# 20                 Donate   Volunteer        Home ...
# 21                                                NaN
# 22                                                NaN
# 23                                 If you are expe...
# 24                                 If you are expe...
#
#                                            text_url21  \
# 0                            Donate              ...
# 1                                                 NaN
# 2                                                 NaN
# 3           SUPPORT US                CONTACT US  ...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                ...
# 20                 Donate   Volunteer        Home ...
# 21                                                NaN
# 22                                                NaN
# 23                                 If you are expe...
# 24                                 If you are expe...
#
#                                            text_url22  \
# 0                            Donate              ...
# 1                                                 NaN
# 2                                                 NaN
# 3           SUPPORT US                CONTACT US  ...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 ...
# 9                                                 NaN
# 10                                                NaN
# 11                                                ...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                ...
# 20                 Donate   Volunteer        Home ...
# 21                                                NaN
# 22                                                NaN
# 23                                                ...
# 24                                                ...
#
#                                            text_url23  \
# 0                            Donate              ...
# 1                                                 NaN
# 2                                                 NaN
# 3           SUPPORT US                CONTACT US  ...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                ...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                ...
# 20                 Donate   Volunteer        Home ...
# 21                                                NaN
# 22                                                NaN
# 23                                 If you are expe...
# 24                                 If you are expe...
#
#                                            text_url24  \
# 0                            Donate              ...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8               Love Another Mother This Mother's ...
# 9                                                 NaN
# 10                                                NaN
# 11                                                ...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                ...
# 20                 Donate   Volunteer        Home ...
# 21                                                NaN
# 22                                                NaN
# 23                                 If you are expe...
# 24                                 If you are expe...
#
#                                            text_url25  \
# 0                            Donate              ...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 ...
# 9                                                 NaN
# 10                                                NaN
# 11              Loading....                 GIVE N...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                ...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                ...
# 24                                                ...
#
#                                             text_base
# 0                                                 NaN
# 1              Facebook                  Door Of H...
# 2                                                 NaN
# 3           SUPPORT US                CONTACT US  ...
# 4                                                 ...
# 5                                                 NaN
# 6                         (530) 897-6101 24 Hour H...
# 7                                                 NaN
# 8                                                 NaN
# 9           Grace Elliott Center 1 Home Services A...
# 10                                                NaN
# 11                                                ...
# 12                                         (951) 2...
# 13                                                NaN
# 14          909-338-0848      Facebook           F...
# 15                                                NaN
# 16                         Skip to content     Liv...
# 17                     Skip to content           C...
# 18                                                NaN
# 19                                                ...
# 20                 Donate   Volunteer        Home ...
# 21                    Toggle navigation           ...
# 22                                 Home    Service...
# 23                                 If you are expe...
# 24                                 If you are expe...
#
# [25 rows x 28 columns]

# %%
def crawling_to_df(state_dict):

    """
    This function starts from a dictionary of state abbreviations and names
    take each state's csv with the CPC urls and generates a csv with the texts 
    and html structures that is exported. 

    Parameters:
        * state_dict: dictionary with the state's abbreviated and complete name
    """

    for stabb, name in state_dict.items():
        # Crawl CPC urls
        try:
            CPCinput = CPCIN + name + " (" + stabb + ").csv"
            CPCoutput = CPCOUT.replace("state", stabb)
            df = csv_extract(CPCinput)
        except FileNotFoundError:
            print(stabb, "file does not exist")
            continue

        # CPC URLs and zip codes
        # Crawl these
        urls = df['url'].tolist()[0:15]

        print("Crawling CPCs in", name)
        network_crawl(urls, LIMIT)[0].to_csv(CPCoutput)
